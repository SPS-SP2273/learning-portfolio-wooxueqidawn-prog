# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
import numpy as np
import matplotlib.pyplot as plt

#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row', sharex = 'col')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -3, color='r', alpha=.125)
axes[0, 0].legend(loc='upper right')
axes[0, 0].set_xlim(-np.pi,np.pi)



#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
axes[0, 1].fill_between(x, sin_x, -2 , color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right')
axes[0, 1].set_xlim(-np.pi,np.pi)


#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend(loc = 'upper right')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].legend(loc = 'upper right')


# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)
    a.grid
plt.tight_layout()
plt.savefig('testing')
plt.show(block=False)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:31: SyntaxWarning: invalid escape sequence '\s'
# <>:39: SyntaxWarning: invalid escape sequence '\s'
# <>:41: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:31: SyntaxWarning: invalid escape sequence '\s'
# <>:39: SyntaxWarning: invalid escape sequence '\s'
# <>:41: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:45: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# <>:53: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:16: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:18: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:19: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:28: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:29: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:31: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:39: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 0].plot(x, fun1_x, color='b', label='$\sin2x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:41: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:45: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:45: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:45: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:45: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:49: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:50: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/mv/34jsqrwd113_ldjh_f0q7kn80000gn/T/ipykernel_2179/2641274846.py:53: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
