# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Footnotes

# %% [markdown]
# ## Exercise 1

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %% [markdown]
# ## Exercise 2

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## Exercise 3

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 172 ns ± 0.966 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 211 ns ± 5.38 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# I will be honest, I did discuss this with my friends but they also did not know so I went to google it. At first i thought that ns meant nanoseconds and that the loop was how many times the code was ran, did not understand the significance of the numbers. I also did not understand why the end result for the 2nd code was produced faster than the end result for the first code.
#
# I think my questions would include the following,
# when i kept the print statement within the code while using %%timeit , the end results for both codes were infinite, as in, infinite number of the same outputs, can I ask why? Can I also ask if the difference in the number of loops between the 2 codes is due to the difference in time (the ns portion)? And if so, why the overall execution time for the 2nd code is still lesser than that of the first code?

# %%
# %%timeit?
# Out:
# Docstring:
# Time execution of a Python statement or expression
#
# **Usage, in line mode**::
#
#   %timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] statement
#
# **or in cell mode**::
#
#   %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] setup_code
#   code
#   code...
#
# Time execution of a Python statement or expression using the timeit
# module.  This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, the statement in the first line is used as setup code
#   (executed but not timed) and the body of the cell is timed.  The cell
#   body has access to any variables created in the setup code.
#
# Options:
#
# -n<N>
#   Execute the given statement N times in a loop. If N is not
#   provided, N is determined so as to get sufficient accuracy.
#
# -r<R>
#   Number of repeats R, each consisting of N loops, and take the
#   average result.
# ...
